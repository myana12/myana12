# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('winequality-red.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.hist(data['quality'])
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
data['quality'].plot(kind="hist",bins=range(3,10,1))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sorted=data['quality'].value_counts()
sorted.plot(kind="bar")
# Out:
# <Axes: xlabel='quality'>

# %%
sorted=data['quality'].value_counts().sort_index()
sorted.plot(kind="bar")
# Out:
# <Axes: xlabel='quality'>

# %%
sorted=data['quality'].value_counts()
sorted.plot(kind="bar")
plt.xticks(rotation=0)
plt.xlabel('quality')
plt.ylabel('winess')
plt.title('wine')
# Out:
# Text(0.5, 1.0, 'wine')

# %%
plt.plot(data['fixed acidity'])
plt.show()

# %%
plt.plot(data['fixed acidity'])
plt.xlim(0,200)
plt.show()

# %%
plt.plot(data['fixed acidity'])
plt.xlim(0,200)
plt.ylim(0,12)
plt.show()

# %%
plt.scatter(x=data['fixed acidity'],y=data['quality'])

# %%
plt.plot(data['fixed acidity'],label='fixed acididty')
plt.plot(data['pH'],label="pH")
plt.legend()
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(data['fixed acidity'])
plt.subplot(1,2,2)
plt.plot(data['pH'])

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.plot(data['fixed acidity'])
